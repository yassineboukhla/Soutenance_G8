# %%
import pandas as pd #importing necessary library
import numpy as np
import matplotlib as plt
import seaborn as sb

# %%
data_read = pd.read_csv('original_dataset.csv') #reading our dataset and stocking it

# %%
data_read.head(35) #showing the 35 first rows
# Out:
#                               company_id  current_loan_amount   loan_term  \
# 0   981165ec-3274-42f5-a3b4-d104041a9ca9             445412.0  Short Term
# 1   2de017a3-2e01-49cb-a581-08169e83be29             262328.0  Short Term
# 2   5efb2b2b-bf11-4dfd-a572-3761a2694725            1000000.0  Short Term
# 3   e777faab-98ae-45af-9a86-7ce5b33b1011             347666.0   Long Term
# 4   81536ad9-5ccf-4eb8-befb-47a4d608658e             176220.0  Short Term
# 5   4ffe99d3-7f2a-44db-afc1-40943f1f9750             206602.0  Short Term
# 6   90a75dde-34d5-419c-90dc-1e58b04b3e35             217646.0  Short Term
# 7   018973c9-e316-4956-b363-67e134fb0931             648714.0   Long Term
# 8   af534dea-d27e-4fd6-9de8-efaa52a78ec0             548746.0  Short Term
# 9   235c4a43-dadf-483d-aa44-9d6d77ae4583             215952.0  Short Term
# 10  0de7bcdb-ebf4-4608-ba39-05f083f855b6                  NaN  Short Term
# 11  aa0a6a22-a95e-48e0-ba4f-b83456d424e4             541970.0  Short Term
# 12  11581f68-de3c-49d8-80d9-22268ebb323b             245023.0  Short Term
# 13  900c9191-2c20-4688-af7e-07c59b5d5a24             560000.0  Short Term
# 14  2ac05980-7848-4692-89ae-9321afe650f8             234124.0  Short Term
# 15  3ec886e7-f15d-4c35-83d0-bdec4817ae4b             449020.0   Long Term
# 16  abb4c446-08ea-49ff-aeb8-5e1e9da673e7             653004.0   Long Term
# 17  967e8733-7189-49b7-a3ab-6a1d0e1abdac             666204.0   Long Term
# 18  c67b2cb5-9f91-4bcb-9a03-03d1589c6c1a              66396.0  Short Term
# 19  422f9b72-5041-407c-8ac4-982213deacd1             390390.0  Short Term
# 20  40f729c9-54c7-4768-9fb5-2fa41d074c48             317108.0   Long Term
# 21  016c5139-4da2-44ba-a0a6-7b23597526a8             128238.0  Short Term
# 22  5b53e176-8fc7-48bf-9d78-ceb5aa284f36             153252.0  Short Term
# 23  eb166545-76e5-43ae-8c64-3fe5ebb9c729              91894.0  Short Term
# 24  54f57722-2473-4dd8-b69b-82b5b0c1c9f9             244926.0   Long Term
# 25  cbe53e22-ba67-4eaf-a4fb-c5acdd12ec66             465410.0   Long Term
# 26  9baf6d5d-f744-4332-abb0-e939b75cde40                  NaN  Short Term
# 27  2bdc133d-cbbf-46c1-a902-488924082993             443960.0  Short Term
# 28  689da294-ff83-4d49-986a-c61887f6d4e2                  NaN  Short Term
# 29  5129cffc-68a1-4dd9-8bfe-035f3478d6dd             107404.0  Short Term
# 30  f4226232-1c33-4d69-ada0-c88245fe345f                  NaN  Short Term
# 31  247c59e9-cf6b-40a7-ae35-d102b69991cc             334620.0  Short Term
# 32  1c9b6b3e-060d-4a70-8b08-522a7f589e89             130174.0  Short Term
# 33  61a4f1ed-e2c3-401e-aec8-9b0d7178f5ff             333564.0   Long Term
# 34  2d53b50a-30a2-488e-a287-3780b26e62ba             109318.0   Long Term
#
#     credit_score  annual_income  years_in_industry  loan_industry  \
# 0          709.0      1167493.0                  8        finance
# 1            NaN            NaN                 10      transport
# 2          741.0      2231892.0                  8     technology
# 3          721.0       806949.0                  3    advertising
# 4            NaN            NaN                  5     technology
# 5         7290.0       896857.0                 10      transport
# 6          730.0      1184194.0                  1    agriculture
# 7            NaN            NaN                  1        finance
# 8          678.0      2559110.0                  2        finance
# 9          739.0      1454735.0                  1      wholesale
# 10         728.0       714628.0                  3        finance
# 11           NaN            NaN                 10     technology
# 12         740.0       776188.0                  1      transport
# 13         743.0      1560907.0                  4         health
# 14         727.0       693234.0                 10      transport
# 15           NaN            NaN                  9     technology
# 16           NaN            NaN                  7  manufacturing
# 17         723.0      1821967.0                 10    agriculture
# 18           NaN            NaN                 10         retail
# 19         747.0      1791738.0                  8        finance
# 20         687.0      1133274.0                  8    real estate
# 21         750.0      1354073.0                  1    agriculture
# 22         714.0      1890690.0                  2      wholesale
# 23         724.0       850383.0                 10    real estate
# 24         704.0      1249953.0                  4        finance
# 25         688.0      1722654.0                  3    real estate
# 26         724.0      1029857.0                  1   construction
# 27         749.0      1432391.0                  2         retail
# 28         746.0      1749748.0                 10     technology
# 29           NaN            NaN                  1      wholesale
# 30         737.0      1501912.0                  6    real estate
# 31         729.0      1348620.0                  2    advertising
# 32         733.0       524609.0                  1      wholesale
# 33         725.0      1248338.0                 10      transport
# 34           NaN            NaN                 10      wholesale
#
#     past_credit_problems business_area  had_bankruptcy  \
# 0                      1         urban             1.0
# 1                      0         urban             0.0
# 2                      1         urban             0.0
# 3                      0         urban             0.0
# 4                      0         urban             0.0
# 5                      0         urban             0.0
# 6                      1         urban             1.0
# 7                      0         urban             0.0
# 8                      0         rural             0.0
# 9                      0         rural             0.0
# 10                     0         rural             0.0
# 11                     0         urban             0.0
# 12                     0         urban             0.0
# 13                     1         urban             1.0
# 14                     1         rural             1.0
# 15                     0         rural             0.0
# 16                     0         urban             0.0
# 17                     0         urban             0.0
# 18                     1         rural             1.0
# 19                     0         rural             0.0
# 20                     0         urban             0.0
# 21                     0         rural             0.0
# 22                     0         rural             0.0
# 23                     0         urban             0.0
# 24                     1         rural             0.0
# 25                     0         urban             0.0
# 26                     0         rural             0.0
# 27                     0         urban             0.0
# 28                     0         rural             0.0
# 29                     0         urban             0.0
# 30                     0         urban             0.0
# 31                     0         rural             0.0
# 32                     1         urban             1.0
# 33                     0         urban             0.0
# 34                     0         urban             0.0
#
#                     property  loan_status
# 0                real estate            0
# 1                real estate            1
# 2                real estate            0
# 3   building society savings            1
# 4               unknown/none            1
# 5               unknown/none            1
# 6   building society savings            0
# 7                      other            0
# 8                real estate            1
# 9                      other            1
# 10                     other            1
# 11  building society savings            1
# 12                     other            0
# 13                     other            0
# 14                     other            0
# 15                     other            1
# 16  building society savings            1
# 17                     other            1
# 18              unknown/none            0
# 19                     other            1
# 20                     other            1
# 21               real estate            0
# 22               real estate            1
# 23  building society savings            1
# 24                     other            1
# 25               real estate            1
# 26                     other            0
# 27               real estate            1
# 28               real estate            1
# 29              unknown/none            1
# 30               real estate            1
# 31                     other            1
# 32                     other            0
# 33              unknown/none            1
# 34  building society savings            1

# %%
data_read.dtypes #showing each column's type
# Out:
# company_id               object
# current_loan_amount     float64
# loan_term                object
# credit_score            float64
# annual_income           float64
# years_in_industry         int64
# loan_industry            object
# past_credit_problems      int64
# business_area            object
# had_bankruptcy          float64
# property                 object
# loan_status               int64
# dtype: object

# %%
data_read.fillna(data_read.mean(), inplace=True) #filling empty boxes with mean value ( valeur moyenne)

# %%
data_read.head(30)
# Out:
#                               company_id  current_loan_amount   loan_term  \
# 0   981165ec-3274-42f5-a3b4-d104041a9ca9        445412.000000  Short Term
# 1   2de017a3-2e01-49cb-a581-08169e83be29        262328.000000  Short Term
# 2   5efb2b2b-bf11-4dfd-a572-3761a2694725       1000000.000000  Short Term
# 3   e777faab-98ae-45af-9a86-7ce5b33b1011        347666.000000   Long Term
# 4   81536ad9-5ccf-4eb8-befb-47a4d608658e        176220.000000  Short Term
# 5   4ffe99d3-7f2a-44db-afc1-40943f1f9750        206602.000000  Short Term
# 6   90a75dde-34d5-419c-90dc-1e58b04b3e35        217646.000000  Short Term
# 7   018973c9-e316-4956-b363-67e134fb0931        648714.000000   Long Term
# 8   af534dea-d27e-4fd6-9de8-efaa52a78ec0        548746.000000  Short Term
# 9   235c4a43-dadf-483d-aa44-9d6d77ae4583        215952.000000  Short Term
# 10  0de7bcdb-ebf4-4608-ba39-05f083f855b6        313919.607022  Short Term
# 11  aa0a6a22-a95e-48e0-ba4f-b83456d424e4        541970.000000  Short Term
# 12  11581f68-de3c-49d8-80d9-22268ebb323b        245023.000000  Short Term
# 13  900c9191-2c20-4688-af7e-07c59b5d5a24        560000.000000  Short Term
# 14  2ac05980-7848-4692-89ae-9321afe650f8        234124.000000  Short Term
# 15  3ec886e7-f15d-4c35-83d0-bdec4817ae4b        449020.000000   Long Term
# 16  abb4c446-08ea-49ff-aeb8-5e1e9da673e7        653004.000000   Long Term
# 17  967e8733-7189-49b7-a3ab-6a1d0e1abdac        666204.000000   Long Term
# 18  c67b2cb5-9f91-4bcb-9a03-03d1589c6c1a         66396.000000  Short Term
# 19  422f9b72-5041-407c-8ac4-982213deacd1        390390.000000  Short Term
# 20  40f729c9-54c7-4768-9fb5-2fa41d074c48        317108.000000   Long Term
# 21  016c5139-4da2-44ba-a0a6-7b23597526a8        128238.000000  Short Term
# 22  5b53e176-8fc7-48bf-9d78-ceb5aa284f36        153252.000000  Short Term
# 23  eb166545-76e5-43ae-8c64-3fe5ebb9c729         91894.000000  Short Term
# 24  54f57722-2473-4dd8-b69b-82b5b0c1c9f9        244926.000000   Long Term
# 25  cbe53e22-ba67-4eaf-a4fb-c5acdd12ec66        465410.000000   Long Term
# 26  9baf6d5d-f744-4332-abb0-e939b75cde40        313919.607022  Short Term
# 27  2bdc133d-cbbf-46c1-a902-488924082993        443960.000000  Short Term
# 28  689da294-ff83-4d49-986a-c61887f6d4e2        313919.607022  Short Term
# 29  5129cffc-68a1-4dd9-8bfe-035f3478d6dd        107404.000000  Short Term
#
#     credit_score  annual_income  years_in_industry  loan_industry  \
# 0      709.00000   1.167493e+06                  8        finance
# 1     1098.33794   1.381647e+06                 10      transport
# 2      741.00000   2.231892e+06                  8     technology
# 3      721.00000   8.069490e+05                  3    advertising
# 4     1098.33794   1.381647e+06                  5     technology
# 5     7290.00000   8.968570e+05                 10      transport
# 6      730.00000   1.184194e+06                  1    agriculture
# 7     1098.33794   1.381647e+06                  1        finance
# 8      678.00000   2.559110e+06                  2        finance
# 9      739.00000   1.454735e+06                  1      wholesale
# 10     728.00000   7.146280e+05                  3        finance
# 11    1098.33794   1.381647e+06                 10     technology
# 12     740.00000   7.761880e+05                  1      transport
# 13     743.00000   1.560907e+06                  4         health
# 14     727.00000   6.932340e+05                 10      transport
# 15    1098.33794   1.381647e+06                  9     technology
# 16    1098.33794   1.381647e+06                  7  manufacturing
# 17     723.00000   1.821967e+06                 10    agriculture
# 18    1098.33794   1.381647e+06                 10         retail
# 19     747.00000   1.791738e+06                  8        finance
# 20     687.00000   1.133274e+06                  8    real estate
# 21     750.00000   1.354073e+06                  1    agriculture
# 22     714.00000   1.890690e+06                  2      wholesale
# 23     724.00000   8.503830e+05                 10    real estate
# 24     704.00000   1.249953e+06                  4        finance
# 25     688.00000   1.722654e+06                  3    real estate
# 26     724.00000   1.029857e+06                  1   construction
# 27     749.00000   1.432391e+06                  2         retail
# 28     746.00000   1.749748e+06                 10     technology
# 29    1098.33794   1.381647e+06                  1      wholesale
#
#     past_credit_problems business_area  had_bankruptcy  \
# 0                      1         urban             1.0
# 1                      0         urban             0.0
# 2                      1         urban             0.0
# 3                      0         urban             0.0
# 4                      0         urban             0.0
# 5                      0         urban             0.0
# 6                      1         urban             1.0
# 7                      0         urban             0.0
# 8                      0         rural             0.0
# 9                      0         rural             0.0
# 10                     0         rural             0.0
# 11                     0         urban             0.0
# 12                     0         urban             0.0
# 13                     1         urban             1.0
# 14                     1         rural             1.0
# 15                     0         rural             0.0
# 16                     0         urban             0.0
# 17                     0         urban             0.0
# 18                     1         rural             1.0
# 19                     0         rural             0.0
# 20                     0         urban             0.0
# 21                     0         rural             0.0
# 22                     0         rural             0.0
# 23                     0         urban             0.0
# 24                     1         rural             0.0
# 25                     0         urban             0.0
# 26                     0         rural             0.0
# 27                     0         urban             0.0
# 28                     0         rural             0.0
# 29                     0         urban             0.0
#
#                     property  loan_status
# 0                real estate            0
# 1                real estate            1
# 2                real estate            0
# 3   building society savings            1
# 4               unknown/none            1
# 5               unknown/none            1
# 6   building society savings            0
# 7                      other            0
# 8                real estate            1
# 9                      other            1
# 10                     other            1
# 11  building society savings            1
# 12                     other            0
# 13                     other            0
# 14                     other            0
# 15                     other            1
# 16  building society savings            1
# 17                     other            1
# 18              unknown/none            0
# 19                     other            1
# 20                     other            1
# 21               real estate            0
# 22               real estate            1
# 23  building society savings            1
# 24                     other            1
# 25               real estate            1
# 26                     other            0
# 27               real estate            1
# 28               real estate            1
# 29              unknown/none            1

# %%
data_read['current_loan_amount'] = data_read['current_loan_amount'].astype('int64') #converting float to int value

# %%
data_read['credit_score'] = data_read['credit_score'].astype('int64') #converting float to int value

# %%
data_read['had_bankruptcy'] = data_read['had_bankruptcy'].astype('int64') #converting float to int value

# %%
data_read['annual_income'] = data_read['annual_income'].astype('int64') #converting float to int value

# %%
data_read.head(30) #Showing our new dataset with no empty boxes after filling them with mean values
# Out:
#                               company_id  current_loan_amount   loan_term  \
# 0   981165ec-3274-42f5-a3b4-d104041a9ca9               445412  Short Term
# 1   2de017a3-2e01-49cb-a581-08169e83be29               262328  Short Term
# 2   5efb2b2b-bf11-4dfd-a572-3761a2694725              1000000  Short Term
# 3   e777faab-98ae-45af-9a86-7ce5b33b1011               347666   Long Term
# 4   81536ad9-5ccf-4eb8-befb-47a4d608658e               176220  Short Term
# 5   4ffe99d3-7f2a-44db-afc1-40943f1f9750               206602  Short Term
# 6   90a75dde-34d5-419c-90dc-1e58b04b3e35               217646  Short Term
# 7   018973c9-e316-4956-b363-67e134fb0931               648714   Long Term
# 8   af534dea-d27e-4fd6-9de8-efaa52a78ec0               548746  Short Term
# 9   235c4a43-dadf-483d-aa44-9d6d77ae4583               215952  Short Term
# 10  0de7bcdb-ebf4-4608-ba39-05f083f855b6               313919  Short Term
# 11  aa0a6a22-a95e-48e0-ba4f-b83456d424e4               541970  Short Term
# 12  11581f68-de3c-49d8-80d9-22268ebb323b               245023  Short Term
# 13  900c9191-2c20-4688-af7e-07c59b5d5a24               560000  Short Term
# 14  2ac05980-7848-4692-89ae-9321afe650f8               234124  Short Term
# 15  3ec886e7-f15d-4c35-83d0-bdec4817ae4b               449020   Long Term
# 16  abb4c446-08ea-49ff-aeb8-5e1e9da673e7               653004   Long Term
# 17  967e8733-7189-49b7-a3ab-6a1d0e1abdac               666204   Long Term
# 18  c67b2cb5-9f91-4bcb-9a03-03d1589c6c1a                66396  Short Term
# 19  422f9b72-5041-407c-8ac4-982213deacd1               390390  Short Term
# 20  40f729c9-54c7-4768-9fb5-2fa41d074c48               317108   Long Term
# 21  016c5139-4da2-44ba-a0a6-7b23597526a8               128238  Short Term
# 22  5b53e176-8fc7-48bf-9d78-ceb5aa284f36               153252  Short Term
# 23  eb166545-76e5-43ae-8c64-3fe5ebb9c729                91894  Short Term
# 24  54f57722-2473-4dd8-b69b-82b5b0c1c9f9               244926   Long Term
# 25  cbe53e22-ba67-4eaf-a4fb-c5acdd12ec66               465410   Long Term
# 26  9baf6d5d-f744-4332-abb0-e939b75cde40               313919  Short Term
# 27  2bdc133d-cbbf-46c1-a902-488924082993               443960  Short Term
# 28  689da294-ff83-4d49-986a-c61887f6d4e2               313919  Short Term
# 29  5129cffc-68a1-4dd9-8bfe-035f3478d6dd               107404  Short Term
#
#     credit_score  annual_income  years_in_industry  loan_industry  \
# 0            709        1167493                  8        finance
# 1           1098        1381647                 10      transport
# 2            741        2231892                  8     technology
# 3            721         806949                  3    advertising
# 4           1098        1381647                  5     technology
# 5           7290         896857                 10      transport
# 6            730        1184194                  1    agriculture
# 7           1098        1381647                  1        finance
# 8            678        2559110                  2        finance
# 9            739        1454735                  1      wholesale
# 10           728         714628                  3        finance
# 11          1098        1381647                 10     technology
# 12           740         776188                  1      transport
# 13           743        1560907                  4         health
# 14           727         693234                 10      transport
# 15          1098        1381647                  9     technology
# 16          1098        1381647                  7  manufacturing
# 17           723        1821967                 10    agriculture
# 18          1098        1381647                 10         retail
# 19           747        1791738                  8        finance
# 20           687        1133274                  8    real estate
# 21           750        1354073                  1    agriculture
# 22           714        1890690                  2      wholesale
# 23           724         850383                 10    real estate
# 24           704        1249953                  4        finance
# 25           688        1722654                  3    real estate
# 26           724        1029857                  1   construction
# 27           749        1432391                  2         retail
# 28           746        1749748                 10     technology
# 29          1098        1381647                  1      wholesale
#
#     past_credit_problems business_area  had_bankruptcy  \
# 0                      1         urban               1
# 1                      0         urban               0
# 2                      1         urban               0
# 3                      0         urban               0
# 4                      0         urban               0
# 5                      0         urban               0
# 6                      1         urban               1
# 7                      0         urban               0
# 8                      0         rural               0
# 9                      0         rural               0
# 10                     0         rural               0
# 11                     0         urban               0
# 12                     0         urban               0
# 13                     1         urban               1
# 14                     1         rural               1
# 15                     0         rural               0
# 16                     0         urban               0
# 17                     0         urban               0
# 18                     1         rural               1
# 19                     0         rural               0
# 20                     0         urban               0
# 21                     0         rural               0
# 22                     0         rural               0
# 23                     0         urban               0
# 24                     1         rural               0
# 25                     0         urban               0
# 26                     0         rural               0
# 27                     0         urban               0
# 28                     0         rural               0
# 29                     0         urban               0
#
#                     property  loan_status
# 0                real estate            0
# 1                real estate            1
# 2                real estate            0
# 3   building society savings            1
# 4               unknown/none            1
# 5               unknown/none            1
# 6   building society savings            0
# 7                      other            0
# 8                real estate            1
# 9                      other            1
# 10                     other            1
# 11  building society savings            1
# 12                     other            0
# 13                     other            0
# 14                     other            0
# 15                     other            1
# 16  building society savings            1
# 17                     other            1
# 18              unknown/none            0
# 19                     other            1
# 20                     other            1
# 21               real estate            0
# 22               real estate            1
# 23  building society savings            1
# 24                     other            1
# 25               real estate            1
# 26                     other            0
# 27               real estate            1
# 28               real estate            1
# 29              unknown/none            1

# %%
encode_cols = data_read.iloc[:,[2,6,8,10]] #extracting categorical columns

# %%
encode_cols.head() #showing extracted categorical columns
# Out:
#     loan_term loan_industry business_area                  property
# 0  Short Term       finance         urban               real estate
# 1  Short Term     transport         urban               real estate
# 2  Short Term    technology         urban               real estate
# 3   Long Term   advertising         urban  building society savings
# 4  Short Term    technology         urban              unknown/none

# %%
from sklearn.preprocessing import LabelEncoder #importing needed library to encode categorical columns

# %%
labelencoder_encode_cols = LabelEncoder() #creating our encoder

# %%
encode_cols.iloc[:,0] = labelencoder_encode_cols.fit_transform(encode_cols.iloc[:,0]) #encoding the fisrt column: loan_term
encode_cols.iloc[:,1] = labelencoder_encode_cols.fit_transform(encode_cols.iloc[:,1]) #encoding the 2nd column: loan_industry
encode_cols.iloc[:,2] = labelencoder_encode_cols.fit_transform(encode_cols.iloc[:,2]) #encoding the 3rd column: business_area
encode_cols.iloc[:,3] = labelencoder_encode_cols.fit_transform(encode_cols.iloc[:,3]) #encoding the 4th column: property
# Out:
# D:\anaconda\lib\site-packages\pandas\core\indexing.py:1047: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item_labels[indexer[info_axis]]] = value
# D:\anaconda\lib\site-packages\pandas\core\indexing.py:965: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
encode_cols.head() #Showing the result of encoding
# Out:
#    loan_term  loan_industry  business_area  property
# 0          1              3              1         2
# 1          1             10              1         2
# 2          1              9              1         2
# 3          0              0              1         0
# 4          1              9              1         3

# %%
from sklearn.preprocessing import LabelEncoder #This code will substitute in our dataset the encoded values
var_mod = ['loan_term','loan_industry','business_area','property']
le = LabelEncoder()
for i in var_mod:
    data_read[i] = le.fit_transform(data_read[i])

# %%
data_read.head() #showing the original dataset with encoded values
# Out:
#                              company_id  current_loan_amount  loan_term  \
# 0  981165ec-3274-42f5-a3b4-d104041a9ca9               445412          1
# 1  2de017a3-2e01-49cb-a581-08169e83be29               262328          1
# 2  5efb2b2b-bf11-4dfd-a572-3761a2694725              1000000          1
# 3  e777faab-98ae-45af-9a86-7ce5b33b1011               347666          0
# 4  81536ad9-5ccf-4eb8-befb-47a4d608658e               176220          1
#
#    credit_score  annual_income  years_in_industry  loan_industry  \
# 0           709        1167493                  8              3
# 1          1098        1381647                 10             10
# 2           741        2231892                  8              9
# 3           721         806949                  3              0
# 4          1098        1381647                  5              9
#
#    past_credit_problems  business_area  had_bankruptcy  property  loan_status
# 0                     1              1               1         2            0
# 1                     0              1               0         2            1
# 2                     1              1               0         2            0
# 3                     0              1               0         0            1
# 4                     0              1               0         3            1

# %%
kendall = data_read.corr(method='kendall') #correlation using Kendall Method

# %%
sb.heatmap(kendall,                            #Heatmap of kendall correlation
            xticklabels=kendall.columns,
            yticklabels=kendall.columns,
            cmap='RdBu_r',
            annot=True,
          linewidth=0.9)

# %%
array = data_read.values # starting to extract necessary columns for building our model

# %%
X = array[:,[1,2,3,4,5,7,9]] #Extracting Independent columns

# %%
Y = array[:,11] #Extracting dependent column

# %%
Y=Y.astype('int')

# %%
from sklearn import model_selection #starting to build our model: Training Phase

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = model_selection.train_test_split(X, Y, test_size=0.25) #75% is for training, 25% is for test

# %%
from sklearn.linear_model import LogisticRegression 
from sklearn.metrics import accuracy_score

# %%
from sklearn.metrics import confusion_matrix, accuracy_score 
model = LogisticRegression()
model.fit(x_train,y_train)
predictions = model.predict(x_test)
print(confusion_matrix(y_test, predictions))
print(accuracy_score(y_test, predictions))
# Out:
# [[  0  72]
#  [  0 178]]
# 0.712

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix, accuracy_score

# %%
DT = DecisionTreeClassifier()
DT.fit(x_train,y_train)
predictions = DT.predict(x_test)
print(confusion_matrix(y_test, predictions))
print(accuracy_score(y_test, predictions))
# Out:
# [[ 70   2]
#  [  1 177]]
# 0.988

# %%
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()
model.fit(x_train,y_train)
predictions = model.predict(x_test)
print(confusion_matrix(y_test, predictions))
print(accuracy_score(y_test, predictions))
# Out:
# [[  0  72]
#  [  0 178]]
# 0.712

# %%
import pickle

# %%
pickle.dump(DT, open('dt_model.pkl', 'wb'))
